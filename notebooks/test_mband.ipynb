# %%
import sys
import os
sys.path.insert(1, '..')

import numpy as np
import scipy as sp
import pandas as pd
from utils import *

import librosa

import matplotlib.pyplot as plt
import seaborn as sns

import IPython.display as ipd

# %%
df = pd.read_csv('../dados/tabela_sinais.csv')

# %%
df
# Out:
#            SIGNAL                            NOISE  NOISE_CUT  EXPECTED_SNR  \
# 0     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      37116           -20
# 1     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac     121404           -10
# 2     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      55870            -5
# 3     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      24885             0
# 4     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac     179835            10
# ...           ...                              ...        ...           ...
# 3145  F181007.WAV   MIX MASTER-start-run-stop.flac      43339            -5
# 3146  F181007.WAV   MIX MASTER-start-run-stop.flac      84687             0
# 3147  F181007.WAV   MIX MASTER-start-run-stop.flac     113949            10
# 3148  F181007.WAV   MIX MASTER-start-run-stop.flac      68716            20
# 3149  F181007.WAV   MIX MASTER-start-run-stop.flac      33450            50
#
#           REAL_SNR  SIGNAL_NAME
# ...

# %%
denoised_speech, _ = librosa.load('../dados/denoised_data/signal_4.wav', sr = None) # Downsample 44.1kHz to 8kHz

# %%
noised_speech, _ = librosa.load('../dados/preprocessed_signals/signal_4.wav', sr = None) # Downsample 44.1kHz to 8kHz

# %%
ipd.Audio(noised_speech, rate= 8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(denoised_speech, rate= 8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(denoised_speech)
# Out:
# 40749

# %%
len(noised_speech)
# Out:
# 40749

# %%
df = pd.read_csv('../dados/tabela_sinais.csv')

# %%
df
# Out:
#            SIGNAL                            NOISE  NOISE_CUT  EXPECTED_SNR  \
# 0     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      37116           -20
# 1     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac     121404           -10
# 2     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      55870            -5
# 3     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac      24885             0
# 4     F180902.WAV  MIXER_HAND_MANUAL-mi#10CFB.flac     179835            10
# ...           ...                              ...        ...           ...
# 3145  F181007.WAV   MIX MASTER-start-run-stop.flac      43339            -5
# 3146  F181007.WAV   MIX MASTER-start-run-stop.flac      84687             0
# 3147  F181007.WAV   MIX MASTER-start-run-stop.flac     113949            10
# 3148  F181007.WAV   MIX MASTER-start-run-stop.flac      68716            20
# 3149  F181007.WAV   MIX MASTER-start-run-stop.flac      33450            50
#
#           REAL_SNR  SIGNAL_NAME
# ...
